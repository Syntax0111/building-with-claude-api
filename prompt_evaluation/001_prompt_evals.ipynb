# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
    Please solve the following task:

    {test_case["task"]}
    """

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def grade_by_model(test_case, output):
    eval_prompt = f"""
    You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.
    
    Original Task:
    <task>
    {test_case["task"]}
    </task>
    
    Solution to Evaluate:
    <solution>
    {output}
    </solution>

    Output Format
    Provide your evaluation as a structured JSON object with the following fields, in this specific order:
    - "strengths": An array of 1-3 key strengths
    - "weaknesses": An array of 1-3 key areas for improvement
    - "reasoning": A concise explanation of your overall assessment
    - "score": A number between 1-10
    
    Respond with JSON. Keep your response concise and direct.
    Example response shape:
    {{
        "strengths": string[],
        "weaknesses": string[],
        "reasoning": string,
        "score": number
    }}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS Region Extraction from S3 URL\n\nHere's a comprehensive solution with multiple approaches:\n\n## Simple Solution\n\n```python\ndef extract_region_from_s3_url(url: str) -> str:\n    \"\"\"\n    Extract AWS region from an S3 bucket URL.\n    \n    Supports formats like:\n    - s3://my-bucket.s3.us-west-2.amazonaws.com/key\n    - https://my-bucket.s3.us-west-2.amazonaws.com/key\n    - s3://bucket-name/key (returns 'us-east-1' as default)\n    \n    Args:\n        url: S3 bucket URL string\n        \n    Returns:\n        Region code (e.g., 'us-west-2') or 'us-east-1' if not found\n    \"\"\"\n    import re\n    \n    # Pattern to match region in S3 URL\n    # Matches: .s3.REGION.amazonaws.com\n    match = re.search(r'\\.s3[.\\-]([a-z0-9\\-]+)\\.amazonaws\\.com', url)\n    \n    if match:\n        return match.group(1)\n    \n    # Default region if not found in URL\n    return 'us-east-1'\n```\n\n## Robust Solution with Multiple Formats\n\n```python\nfrom typing import Optional\nimport re\n\ndef extract_region_from_s3_url(url: str) -> Optional[str]:\n    \"\"\"\n    Extract AWS region from various S3 URL formats.\n    \n    Supports:\n    - Virtual-hosted-style: https://bucket-name.s3.region.amazonaws.com/key\n    - Virtual-hosted-style (old): https://bucket-name.s3.amazonaws.com/key\n    - Path-style: https://s3.region.amazonaws.com/bucket-name/key\n    - S3 protocol: s3://bucket-name.s3.region.amazonaws.com/key\n    \n    Args:\n        url: S3 bucket URL string\n        \n    Returns:\n        Region code (e.g., 'us-west-2') or None if region not found\n    \"\"\"\n    \n    patterns = [\n        # Virtual-hosted-style with region: bucket.s3.region.amazonaws.com\n        r'\\.s3[.\\-]([a-z0-9\\-]+)\\.amazonaws\\.com',\n        # Path-style with region: s3.region.amazonaws.com\n        r's3[.\\-]([a-z0-9\\-]+)\\.amazonaws\\.com',\n    ]\n    \n    for pattern in patterns:\n        match = re.search(pattern, url)\n        if match:\n            region = match.group(1)\n            # Validate it looks like a region code\n            if re.match(r'^[a-z]{2}-[a-z]+-\\d+$', region):\n                return region\n    \n    return None\n```\n\n## Complete Solution with Error Handling\n\n```python\nfrom typing import Optional\nfrom urllib.parse import urlparse\nimport re\n\ndef extract_region_from_s3_url(url: str, default_region: str = 'us-east-1') -> str:\n    \"\"\"\n    Extract AWS region from an S3 URL with comprehensive error handling.\n    \n    Args:\n        url: S3 bucket URL\n        default_region: Default region to return if not found\n        \n    Returns:\n        AWS region code\n        \n    Raises:\n        ValueError: If URL is invalid\n    \"\"\"\n    \n    if not url:\n        raise ValueError(\"URL cannot be empty\")\n    \n    # Normalize the URL\n    url = url.strip()\n    \n    # Pattern to match regions in S3 URLs\n    # Matches patterns like: .s3.us-west-2.amazonaws.com or .s3-us-west-2.amazonaws.com\n    pattern = r'\\.s3[.\\-]([a-z0-9\\-]+)\\.amazonaws\\.com'\n    match = re.search(pattern, url)\n    \n    if match:\n        region = match.group(1)\n        # Validate region format (e.g., us-west",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS region from an S3 bucket URL like 's3://my-bucket.s3.us-west-2.amazonaws.com/key'. The function should return just the region code (e.g., 'us-west-2')."
#     },
#     "score": 5,
#     "reasoning": "The solution demonstrates good understanding of S3 URL formats and provides well-documented examples. However, it suffers from a critical issue: the code is incomplete with the main example cutting off mid-function. Additionally, there are logical flaws in the region validation pattern that would reject valid AWS regions. The inconsistent API design (returning None vs default region) between versions creates confusion about best practices. While the regex patterns for URL matching are sound, the overall solution feels rushed and unfinished."
#   },
#   {
#     "output": "# AWS IAM Policy for S3 Access\n\nHere's a JSON object that represents an AWS IAM policy with the requested permissions:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:PutObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-application-bucket/*\"\n    }\n  ]\n}\n```\n\n## Explanation\n\n- **Version**: `2012-10-17` is the current policy language version\n- **Statement**: Array containing the policy rules\n  - **Effect**: `Allow` grants the permissions\n  - **Action**: Array of S3 actions allowed:\n    - `s3:GetObject` - allows reading/downloading objects\n    - `s3:PutObject` - allows uploading/writing objects\n  - **Resource**: The ARN (Amazon Resource Name) specifying:\n    - `arn:aws:s3:::my-application-bucket/*` - all objects (`/*`) in the bucket\n    - Note: The `/*` wildcard is essential for object-level permissions\n\n## Optional Additions\n\nIf you also need to list the bucket contents, add this statement:\n\n```json\n{\n  \"Effect\": \"Allow\",\n  \"Action\": \"s3:ListBucket\",\n  \"Resource\": \"arn:aws:s3:::my-application-bucket\"\n}\n```",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing a principal to perform 's3:GetObject' and 's3:PutObject' actions on all objects in the bucket 'my-application-bucket'."
#     },
#     "score": 8,
#     "reasoning": "The solution correctly addresses the core requirement by providing a valid IAM policy with proper S3 permissions and resource ARN syntax. The explanation is clear and educational. However, it lacks mention of the principal/identity aspect of policy attachment, which is important for understanding how this policy would be used in practice. The policy itself is accurate and production-ready, with thoughtful optional additions suggested."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Component | Purpose |\n|-----------|---------|\n| `^` | Start of string anchor |\n| `i-` | Literal prefix \"i-\" |\n| `[0-9a-f]` | Character class matching hexadecimal digits (0-9, a-f) |\n| `{17}` | Exactly 17 occurrences of the preceding character class |\n| `$` | End of string anchor |\n\n## Examples\n\n**Matches:**\n- `i-0abcd1234efgh5678` \u2705\n- `i-1a2b3c4d5e6f7g8h9` \u2705\n- `i-0000000000000000a` \u2705\n\n**Does not match:**\n- `i-0abcd1234efgh567` \u274c (only 16 characters)\n- `i-0abcd1234efgh56789` \u274c (18 characters)\n- `I-0abcd1234efgh5678` \u274c (uppercase I)\n- `0abcd1234efgh5678` \u274c (missing \"i-\" prefix)\n\n## Language-Specific Examples\n\n**Python:**\n```python\nimport re\npattern = r'^i-[0-9a-f]{17}$'\nif re.match(pattern, 'i-0abcd1234efgh5678'):\n    print(\"Valid EC2 Instance ID\")\n```\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\nif (pattern.test('i-0abcd1234efgh5678')) {\n    console.log(\"Valid EC2 Instance ID\");\n}\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: 'i-' followed by 17 hexadecimal characters, e.g., 'i-0abcd1234efgh5678')."
#     },
#     "score": 5,
#     "reasoning": "The regex pattern itself is technically correct for matching 'i-' followed by exactly 17 lowercase hexadecimal characters. However, the provided examples contain critical errors that demonstrate invalid instance IDs being marked as valid matches. The examples use 'g' and 'h' characters which fall outside the [0-9a-f] range defined in the regex. This inconsistency significantly undermines the credibility of the solution and could mislead users. The explanation and code examples are otherwise well-structured and clear."
#   }
# ]
